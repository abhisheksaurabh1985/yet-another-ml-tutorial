# %% [markdown]
# ## Gaussian Mixture Model

# %% [markdown]
# Goal: To predict if the players will continue playing the game next month or not. Classify if the customer is going to churn or not. Given, a single data point. The amount of money the user has either withdrawn or deposited.

# %% [markdown]
# GMM: Generative unsupervised model for clustering aka EM clustering.
#
# Each point is generated by linearly combining multiple Gaussians.
